# %% [markdown]
# # Knowing the data

# %%
import pandas as pd

# Set max columns to None
pd.set_option('display.max_columns', None)

# %%
def check_dif_dfs(df1, df2):
    colunas_df1 = set(df1.columns)
    colunas_df2 = set(df2.columns)

    colunas_diferentes = colunas_df1.symmetric_difference(colunas_df2)
    qtde_colunas_diferentes = len(colunas_diferentes)

    if qtde_colunas_diferentes > 0:
        print("As colunas diferentes são:", qtde_colunas_diferentes)
        for coluna in colunas_diferentes:
            print(coluna)
    else:
        print("Os DataFrames têm as mesmas colunas.")

# %% [markdown]
# ### BenefitsCostSharing

# %%
benefCostSharing_2016_df = pd.read_csv('../data/archive/raw/2016/Benefits_Cost_Sharing_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)

print(benefCostSharing_2016_df.shape)
benefCostSharing_2016_df.columns
# Out:
# (1804253, 30)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'IssuerId2', 'StateCode2', 'StandardComponentId',
#        'PlanId', 'BenefitName', 'CopayInnTier1', 'CopayInnTier2',
#        'CopayOutofNet', 'CoinsInnTier1', 'CoinsInnTier2', 'CoinsOutofNet',
#        'IsEHB', 'IsStateMandate', 'IsCovered', 'QuantLimitOnSvc', 'LimitQty',
#        'LimitUnit', 'MinimumStay', 'Exclusions', 'Explanation', 'EHBVarReason',
#        'IsExclFromInnMOOP', 'IsExclFromOonMOOP', 'RowNumber'],
#       dtype='object')

# %%
benefCostSharing_2015_df = pd.read_csv('../data/archive/raw/2015/Benefits_Cost_Sharing_PUF.csv', encoding="latin1", low_memory=False)
benefCostSharing_2015_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum     ImportDate  \
# 0          2015        AZ     12303       HIOS           5  9/3/2014 4:28
# 1          2015        AZ     12303       HIOS           5  9/3/2014 4:28
# 2          2015        AZ     12303       HIOS           5  9/3/2014 4:28
# 3          2015        AZ     12303       HIOS           5  9/3/2014 4:28
# 4          2015        AZ     12303       HIOS           5  9/3/2014 4:28
#
#    IssuerId2 StateCode2 StandardComponentId             PlanId  \
# 0      12303         AZ      12303AZ0010003  12303AZ0010003-00
# 1      12303         AZ      12303AZ0010003  12303AZ0010003-00
# 2      12303         AZ      12303AZ0010003  12303AZ0010003-00
# 3      12303         AZ      12303AZ0010003  12303AZ0010003-00
# 4      12303         AZ      12303AZ0010003  12303AZ0010003-00
#
#                     BenefitName               CopayInnTier1 CopayInnTier2  \
# ...

# %%
benefCostSharing_df = pd.read_csv('../data/archive/raw/2014/Benefits_Cost_Sharing_PUF.csv', encoding="latin1", low_memory=False)
print(benefCostSharing_df.shape)
benefCostSharing_df.columns
# Out:
# (1164869, 32)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'IssuerId2', 'StateCode2', 'StandardComponentId',
#        'PlanId', 'BenefitName', 'CopayInnTier1', 'CopayInnTier2',
#        'CopayOutofNet', 'CoinsInnTier1', 'CoinsInnTier2', 'CoinsOutofNet',
#        'IsEHB', 'IsStateMandate', 'IsCovered', 'QuantLimitOnSvc', 'LimitQty',
#        'LimitUnit', 'MinimumStay', 'Exclusions', 'Explanation', 'EHBVarReason',
#        'IsSubjToDedTier1', 'IsSubjToDedTier2', 'IsExclFromInnMOOP',
#        'IsExclFromOonMOOP', 'RowNumber'],
#       dtype='object')

# %%
print('base 2014')
print(benefCostSharing_df.shape)
print('base 2015')
print(benefCostSharing_2015_df.shape)
print('base 2016')
print(benefCostSharing_2016_df.shape)
# Out:
# base 2014
# (1164869, 32)
# base 2015
# (2079286, 32)
# base 2016
# (1804253, 30)

# %%
print('colunas 2014 e 2015')
check_dif_dfs(benefCostSharing_df, benefCostSharing_2015_df)
print('colunas 2015 e 2016')
check_dif_dfs(benefCostSharing_2015_df, benefCostSharing_2016_df)
# Out:
# colunas 2014 e 2015
# Os DataFrames têm as mesmas colunas.
# colunas 2015 e 2016
# As colunas diferentes são: 2
# IsSubjToDedTier2
# IsSubjToDedTier1

# %% [markdown]
# ### Business Rules

# %%
business_rules_2014_df = pd.read_csv('../data/archive/raw/2014/Business_Rules_PUF.csv', encoding="latin1", low_memory=False)
business_rules_2014_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AL     82285       HIOS           7
# 1          2014        AL     82285       HIOS           7
# 2          2014        AL     82285       HIOS           7
# 3          2014        AL     82285       HIOS           7
# 4          2014        AL     82285       HIOS           7
#
#             ImportDate  IssuerId2         TIN ProductId StandardComponentId  \
# 0  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0010006
# 1  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020001
# 2  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020002
# 3  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020004
# 4  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020006
#
#                EnrolleeContractRateDeterminationRule  \
# 0  A different rate (specifically for parties of ...
# ...

# %%
business_rules_refor_df = pd.read_csv('../data/archive/raw/2015/Business_Rules_PUF_Reformat.csv', encoding="latin1", low_memory=False)
business_rules_refor_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2015        AK     73836       HIOS          15
# 1          2015        AK     73836       HIOS          15
# 2          2015        AK     73836       HIOS          15
# 3          2015        AK     73836       HIOS          15
# 4          2015        AK     73836       HIOS          15
#
#             ImportDate  IssuerId2         TIN   ProductId StandardComponentId  \
# 0  2015-04-22 11:06:15      73836  93-0989307  73836AK073      73836AK0730003
# 1  2015-04-22 11:06:15      73836  93-0989307  73836AK073      73836AK0730004
# 2  2015-04-22 11:06:15      73836  93-0989307  73836AK073      73836AK0730005
# 3  2015-04-22 11:06:15      73836  93-0989307  73836AK073      73836AK0730006
# 4  2015-04-22 11:06:15      73836  93-0989307  73836AK074      73836AK0740001
#
#                EnrolleeContractRateDeterminationRule  \
# 0  A different rate (specifically for parties of ...
# ...

# %%
check_dif_dfs(business_rules_2014_df, business_rules_refor_df)
# Out:
# Os DataFrames têm as mesmas colunas.

# %%
business_rules_df = pd.read_csv('../data/archive/raw/2016/Business_Rules_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)
business_rules_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2016        AK     21989       HIOS           4
# 1          2016        AK     21989       HIOS           4
# 2          2016        AK     21989       HIOS           4
# 3          2016        AK     21989       HIOS           4
# 4          2016        AK     21989       HIOS           4
#
#             ImportDate  IssuerId2         TIN   ProductId StandardComponentId  \
# 0  2015-08-22 15:09:32      21989  93-0438772  21989AK009      21989AK0090001
# 1  2015-08-22 15:09:32      21989  93-0438772  21989AK009      21989AK0090002
# 2  2015-08-22 15:09:32      21989  93-0438772  21989AK010      21989AK0100001
# 3  2015-08-22 15:09:32      21989  93-0438772  21989AK010      21989AK0100002
# 4  2015-08-22 15:09:32      21989  93-0438772  21989AK011      21989AK0110001
#
#                EnrolleeContractRateDeterminationRule  \
# 0  There are rates specifically for couples and f...
# ...

# %%
check_dif_dfs(business_rules_df, business_rules_refor_df)
# Out:
# As colunas diferentes são: 2
# DentalOnlyPlan
# DentalOnly

# %% [markdown]
# ### Crosswak

# %%
crosswalk_2015_df = pd.read_csv('../data/archive/raw/2015/Plan_Crosswalk_PUF_2014-12-22.csv', encoding="latin1", low_memory=False)
crosswalk_2015_df.head(5)
# Out:
#   State DentalPlan     PlanID_2014  IssuerID_2014 MultistatePlan_2014  \
# 0    AK          Y  21989AK0010001          21989                   N
# 1    AK          Y  21989AK0010001          21989                   N
# 2    AK          Y  21989AK0010001          21989                   N
# 3    AK          Y  21989AK0010001          21989                   N
# 4    AK          Y  21989AK0010001          21989                   N
#
#   MetalLevel_2014  ChildAdultOnly_2014  FIPSCode  ZipCode  CrosswalkLevel  \
# 0             Low                    0      2013        0               1
# 1             Low                    0      2016        0               1
# 2             Low                    0      2020        0               1
# 3             Low                    0      2050        0               1
# 4             Low                    0      2060        0               1
#
#    ReasonForCrosswalk     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# ...

# %%
crosswalk_2016_df = pd.read_csv('../data/archive/raw/2016/Plan_ID_Crosswalk_PUF_2015-12-07.CSV', encoding="latin1", low_memory=False)
crosswalk_2016_df.head(5)
# Out:
#   State DentalPlan     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# 0    OR          N  10091OR0360004          10091                   N
# 1    OR          N  10091OR0360004          10091                   N
# 2    OR          N  10091OR0360004          10091                   N
# 3    OR          N  10091OR0360004          10091                   N
# 4    OR          N  10091OR0360004          10091                   N
#
#   MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  ZipCode  CrosswalkLevel  \
# 0          Bronze                    0     41021        0               0
# 1          Bronze                    0     41037        0               0
# 2          Bronze                    0     41009        0               0
# 3          Bronze                    0     41023        0               0
# 4          Bronze                    0     41059        0               0
#
#    ReasonForCrosswalk     PlanID_2016  IssuerID_2016 MultistatePlan_2016  \
# ...

# %% [markdown]
# ### Network

# %%
net_work_2016_df = pd.read_csv('../data/archive/raw/2016/Network_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)
net_work_2016_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2016        AK     21989       HIOS           4
# 1          2016        AK     21989       HIOS           4
# 2          2016        AK     38344       HIOS          10
# 3          2016        AK     38344       HIOS          10
# 4          2016        AK     38344       HIOS          10
#
#             ImportDate  IssuerId2 StateCode2              NetworkName  \
# 0  2015-08-22 15:09:32      21989         AK     Delta Dental Premier
# 1  2015-08-22 15:09:32      21989         AK         Delta Dental PPO
# 2  2015-08-25 05:06:23      38344         AK  HeritagePlus and Dental
# 3  2015-08-25 05:06:23      38344         AK                   Dental
# 4  2015-08-25 05:06:23      38344         AK             HeritagePlus
#
#   NetworkId                                         NetworkURL  RowNumber  \
# 0    AKN001  https://www.modahealth.com/ProviderSearch/face...         13
# ...

# %%
net_work_2015_df = pd.read_csv('../data/archive/raw/2015/Network_PUF.csv', encoding="latin1", low_memory=False)
net_work_2015_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2015        GA     89942       HIOS           7
# 1          2015        GA     93332       HIOS          10
# 2          2015        GA     93332       HIOS          10
# 3          2015        GA     93332       HIOS          10
# 4          2015        GA     93332       HIOS          10
#
#             ImportDate  IssuerId2 StateCode2            NetworkName NetworkId  \
# 0  2015-02-19 06:21:02      89942         GA  Kaiser Permanente HMO    GAN001
# 1  2014-09-29 21:43:29      93332         GA           Atlanta HMOx    GAN001
# 2  2014-09-29 21:43:29      93332         GA      Columbus, GA HMOx    GAN002
# 3  2014-09-29 21:43:29      93332         GA          Savannah HMOx    GAN003
# 4  2014-09-29 21:43:29      93332         GA             Macon HMOx    GAN005
#
#                                           NetworkURL  RowNumber  \
# 0                                  kp.org/gaprovider         13
# ...

# %%
print(net_work_2016_df.shape)
print(net_work_2016_df.columns)

print('2015:')
print(net_work_2015_df.shape)
print(net_work_2015_df.columns)
# Out:
# (1426, 14)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'IssuerId2', 'StateCode2', 'NetworkName', 'NetworkId',
#        'NetworkURL', 'RowNumber', 'MarketCoverage', 'DentalOnlyPlan'],
#       dtype='object')
# 2015:
# (1459, 14)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'IssuerId2', 'StateCode2', 'NetworkName', 'NetworkId',
#        'NetworkURL', 'RowNumber', 'MarketCoverage', 'DentalOnly'],
#       dtype='object')

# %%
check_dif_dfs(net_work_2016_df, net_work_2015_df)
# Out:
# As colunas diferentes são: 2
# DentalOnlyPlan
# DentalOnly

# %% [markdown]
# ### Plan attributes

# %%
plan_attributes_2014_df = pd.read_csv('../data/archive/raw/2014/Plan_Attributes_PUF_2014_2015-03-09.csv', encoding="latin1", low_memory=False)
plan_attributes_2014_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AK     21989       HIOS           6
# 1          2014        AK     21989       HIOS           6
# 2          2014        AK     21989       HIOS           6
# 3          2014        AK     21989       HIOS           6
# 4          2014        AK     21989       HIOS           6
#
#             ImportDate  BenefitPackageId  IssuerId2 StateCode2  \
# 0  2014-03-19 07:06:49                 1      21989         AK
# 1  2014-03-19 07:06:49                 1      21989         AK
# 2  2014-03-19 07:06:49                 1      21989         AK
# 3  2014-03-19 07:06:49                 1      21989         AK
# 4  2014-03-19 07:06:49                 1      21989         AK
#
#        MarketCoverage DentalOnlyPlan         TIN StandardComponentId  \
# 0  SHOP (Small Group)            Yes  93-0438772      21989AK0020002
# 1  SHOP (Small Group)            Yes  93-0438772      21989AK0020002
# ...

# %%
plan_attributes_2016_df = pd.read_csv('../data/archive/raw/2016/Plan_Attributes_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)
plan_attributes_2016_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum       ImportDate  \
# 0          2016        AK     21989       HIOS           4  8/22/2015 15:09
# 1          2016        AK     21989       HIOS           4  8/22/2015 15:09
# 2          2016        AK     21989       HIOS           4  8/22/2015 15:09
# 3          2016        AK     21989       HIOS           4  8/22/2015 15:09
# 4          2016        AK     21989       HIOS           4  8/22/2015 15:09
#
#    BenefitPackageId  IssuerId2 StateCode2      MarketCoverage DentalOnlyPlan  \
# 0                 1      21989         AK          Individual            Yes
# 1                 1      21989         AK  SHOP (Small Group)            Yes
# 2                 1      21989         AK          Individual            Yes
# 3                 2      21989         AK          Individual            Yes
# 4                 2      21989         AK  SHOP (Small Group)            Yes
#
# ...

# %%
plan_attributes_2015_df = pd.read_csv('../data/archive/raw/2015/Plan_Attributes_PUF.csv', encoding="latin1", low_memory=False)
plan_attributes_2015_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2015        AK     21989       HIOS           4
# 1          2015        AK     21989       HIOS           4
# 2          2015        AK     38344       HIOS           8
# 3          2015        AK     38344       HIOS           8
# 4          2015        AK     73836       HIOS          15
#
#             ImportDate  BenefitPackageId  IssuerId2 StateCode2  \
# 0  2014-08-08 08:53:29                 1      21989         AK
# 1  2014-08-08 08:53:29                 1      21989         AK
# 2  2014-10-02 12:25:15                 1      38344         AK
# 3  2014-10-02 12:25:15                 1      38344         AK
# 4  2015-04-22 11:06:15                 2      73836         AK
#
#        MarketCoverage DentalOnlyPlan         TIN StandardComponentId  \
# 0          Individual            Yes  93-0438772      21989AK0030001
# 1          Individual            Yes  93-0438772      21989AK0030001
# ...

# %%
print('2014:')
print(plan_attributes_2014_df.shape)
print(plan_attributes_2014_df.columns)

print('2015:')
print(plan_attributes_2015_df.shape)

print('now:')
print(plan_attributes_2016_df.shape)
print(plan_attributes_2016_df.columns)
# Out:
# 2014:
# (18719, 126)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'BenefitPackageId', 'IssuerId2', 'StateCode2',
#        'MarketCoverage',
#        ...
#        'TEHBDedCombInnOonFamily', 'SBCHavingaBabyDeductible',
#        'SBCHavingaBabyCopayment', 'SBCHavingaBabyCoinsurance',
#        'SBCHavingaBabyLimit', 'SBCHavingDiabetesDeductible',
#        'SBCHavingDiabetesCopayment', 'SBCHavingDiabetesCoinsurance',
#        'SBCHavingDiabetesLimit', 'RowNumber'],
#       dtype='object', length=126)
# 2015:
# (31253, 126)
# now:
# (27381, 151)
# Index(['BusinessYear', 'StateCode', 'IssuerId', 'SourceName', 'VersionNum',
#        'ImportDate', 'BenefitPackageId', 'IssuerId2', 'StateCode2',
#        'MarketCoverage',
#        ...
#        'TEHBDedOutOfNetFamilyPerGroup', 'TEHBDedCombInnOonIndividual',
#        'TEHBDedCombInnOonFamilyPerPerson', 'TEHBDedCombInnOonFamilyPerGroup',
# ...

# %%
check_dif_dfs(plan_attributes_2014_df, plan_attributes_2016_df)
# Out:
# As colunas diferentes são: 75
# DEHBCombInnOonFamilyPerPersonMOOP
# MEHBInnTier2FamilyPerPersonMOOP
# TEHBInnTier2FamilyMOOP
# TEHBDedInnTier1Family
# MEHBInnTier1FamilyMOOP
# MEHBInnTier2FamilyMOOP
# TEHBCombInnOonFamilyPerGroupMOOP
# MEHBDedOutOfNetFamilyPerGroup
# DEHBDedOutOfNetFamily
# DEHBDedInnTier2FamilyPerGroup
# MEHBDedInnTier2FamilyPerGroup
# TEHBInnTier1FamilyPerPersonMOOP
# TEHBInnTier1FamilyPerGroupMOOP
# TEHBInnTier1FamilyMOOP
# TEHBOutOfNetFamilyMOOP
# DEHBCombInnOonFamilyPerGroupMOOP
# MEHBDedInnTier2FamilyPerPerson
# TEHBDedInnTier2Family
# DEHBInnTier2FamilyPerGroupMOOP
# TEHBDedInnTier2FamilyPerPerson
# TEHBDedOutOfNetFamilyPerGroup
# DEHBDedCombInnOonFamilyPerGroup
# MEHBInnTier2FamilyPerGroupMOOP
# DEHBDedInnTier2FamilyPerPerson
# DEHBInnTier1FamilyMOOP
# DEHBDedInnTier1Family
# TEHBInnTier2FamilyPerGroupMOOP
# TEHBCombInnOonFamilyMOOP
# DEHBOutOfNetFamilyPerPersonMOOP
# DEHBInnTier2FamilyPerPersonMOOP
# MEHBCombInnOonFamilyMOOP
# TEHBDedInnTier1FamilyPerGroup
# ...

# %%
check_dif_dfs(plan_attributes_2014_df, plan_attributes_2015_df)
# Out:
# Os DataFrames têm as mesmas colunas.

# %% [markdown]
# ### Rate

# %%
rate_2014_df = pd.read_csv('../data/archive/raw/2014/Rate_PUF.csv', encoding="latin1", low_memory=False)
rate_2014_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AK     21989       HIOS           6
# 1          2014        AK     21989       HIOS           6
# 2          2014        AK     21989       HIOS           6
# 3          2014        AK     21989       HIOS           6
# 4          2014        AK     21989       HIOS           6
#
#             ImportDate  IssuerId2  FederalTIN RateEffectiveDate  \
# 0  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 1  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 2  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 3  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 4  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
#
#   RateExpirationDate          PlanId   RatingAreaId        Tobacco  \
# 0         2014-12-31  21989AK0010001  Rating Area 1  No Preference
# 1         2014-12-31  21989AK0020001  Rating Area 1  No Preference
# ...

# %%
rate_2015_df = pd.read_csv('../data/archive/raw/2015/Rate_PUF.csv', encoding="latin1", low_memory=False)
rate_2015_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2015        AK     21989       HIOS           4
# 1          2015        AK     21989       HIOS           4
# 2          2015        AK     21989       HIOS           4
# 3          2015        AK     21989       HIOS           4
# 4          2015        AK     21989       HIOS           4
#
#             ImportDate  IssuerId2  FederalTIN RateEffectiveDate  \
# 0  2014-08-08 08:53:29      21989  93-0438772        2015-01-01
# 1  2014-08-08 08:53:29      21989  93-0438772        2015-01-01
# 2  2014-08-08 08:53:29      21989  93-0438772        2015-01-01
# 3  2014-08-08 08:53:29      21989  93-0438772        2015-01-01
# 4  2014-08-08 08:53:29      21989  93-0438772        2015-01-01
#
#   RateExpirationDate          PlanId   RatingAreaId        Tobacco   Age  \
# 0         2015-12-31  21989AK0030001  Rating Area 1  No Preference  0-20
# 1         2015-12-31  21989AK0030001  Rating Area 1  No Preference    21
# ...

# %%
rate_2016_df = pd.read_csv('../data/archive/raw/2016/Rate_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)
rate_2016_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2016        AK     21989       HIOS           4
# 1          2016        AK     21989       HIOS           4
# 2          2016        AK     21989       HIOS           4
# 3          2016        AK     21989       HIOS           4
# 4          2016        AK     21989       HIOS           4
#
#             ImportDate  IssuerId2  FederalTIN RateEffectiveDate  \
# 0  2015-08-22 15:09:32      21989  93-0438772        2016-01-01
# 1  2015-08-22 15:09:32      21989  93-0438772        2016-01-01
# 2  2015-08-22 15:09:32      21989  93-0438772        2016-04-01
# 3  2015-08-22 15:09:32      21989  93-0438772        2016-01-01
# 4  2015-08-22 15:09:32      21989  93-0438772        2016-04-01
#
#   RateExpirationDate          PlanId   RatingAreaId        Tobacco  \
# 0         2016-12-31  21989AK0030001  Rating Area 1  No Preference
# 1         2016-03-31  21989AK0080001  Rating Area 1  No Preference
# ...

# %%
check_dif_dfs(rate_2016_df, rate_2015_df)
check_dif_dfs(rate_2014_df, rate_2015_df)
# Out:
# Os DataFrames têm as mesmas colunas.
# Os DataFrames têm as mesmas colunas.

# %% [markdown]
# ### Service area

# %%
service_area_2014_df = pd.read_csv('../data/archive/raw/2014/Service_Area_PUF.csv', encoding="latin1", low_memory=False)
service_area_2014_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        PA     22444       HIOS           9
# 1          2014        PA     22444       HIOS           9
# 2          2014        PA     22444       HIOS           9
# 3          2014        PA     22444       HIOS           9
# 4          2014        PA     22444       HIOS           9
#
#             ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# 0  2014-01-21 08:29:49      22444         PA        PAS001
# 1  2014-01-21 08:29:49      22444         PA        PAS001
# 2  2014-01-21 08:29:49      22444         PA        PAS001
# 3  2014-01-21 08:29:49      22444         PA        PAS001
# 4  2014-01-21 08:29:49      22444         PA        PAS001
#
#          ServiceAreaName CoverEntireState   County PartialCounty ZipCodes  \
# 0  Geisinger Health Plan               No  42103.0            No      NaN
# 1  Geisinger Health Plan               No  42105.0            No      NaN
# ...

# %%
service_area_2015_df = pd.read_csv('../data/archive/raw/2015/Service_Area_PUF.csv', encoding="latin1", low_memory=False)
service_area_2015_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2015        PA     70406       HIOS           2
# 1          2015        PA     70406       HIOS           2
# 2          2015        PA     70406       HIOS           2
# 3          2015        PA     70406       HIOS           2
# 4          2015        PA     70406       HIOS           2
#
#             ImportDate  IssuerId2 StateCode2 ServiceAreaId ServiceAreaName  \
# 0  2014-08-05 13:28:44      70406         PA        PAS001    Pennsylvania
# 1  2014-08-05 13:28:44      70406         PA        PAS001    Pennsylvania
# 2  2014-08-05 13:28:44      70406         PA        PAS001    Pennsylvania
# 3  2014-08-05 13:28:44      70406         PA        PAS001    Pennsylvania
# 4  2014-08-05 13:28:44      70406         PA        PAS001    Pennsylvania
#
#   CoverEntireState   County PartialCounty ZipCodes PartialCountyJustification  \
# ...

# %%
service_area_2016_df = pd.read_csv('../data/archive/raw/2016/ServiceArea_PUF_2015-12-08.csv', encoding="latin1", low_memory=False)
service_area_2016_df.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2016        NJ     10191       HIOS           6
# 1          2016        NJ     10191       HIOS           6
# 2          2016        NJ     10191       HIOS           6
# 3          2016        NJ     10191       HIOS           6
# 4          2016        NJ     10191       HIOS           6
#
#             ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# 0  2015-11-18 07:25:09      10191         NJ        NJS003
# 1  2015-11-18 07:25:09      10191         NJ        NJS004
# 2  2015-11-18 07:25:09      10191         NJ        NJS004
# 3  2015-11-18 07:25:09      10191         NJ        NJS004
# 4  2015-11-18 07:25:09      10191         NJ        NJS004
#
#          ServiceAreaName CoverEntireState   County PartialCounty  \
# 0  Monmouth/Centra State               No  34029.0           Yes
# 1                   PCMH               No  34001.0            No
# ...

# %%
check_dif_dfs(service_area_2015_df, service_area_2016_df)
check_dif_dfs(service_area_2015_df, service_area_2014_df)
# Out:
# As colunas diferentes são: 2
# DentalOnlyPlan
# DentalOnly
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 check_dif_dfs(service_area_2015_df, service_area_2016_df)
# ----> 2 check_dif_dfs(service_area_2015_df, service_area_2014_df)
#
# NameError: name 'service_area_2014_df' is not defined

# %%
tables = {
    "BenefitsCostSharing": {
        # 2016 removed two fields: 'IsSubjToDedTier2', 'IsSubjToDedTier1
        "2016": "BenefitsCostSharing_2016.parquet",
        "2015": "BenefitsCostSharing_2015.parquet",
        "2014": "BenefitsCostSharing_2014.parquet"
    },
    "BusinessRules": {
        # 2016 renamed DentalOnly => DentalOnlyPlan
        "2016": "BusinessRules_2016.parquet",
        "2015": "BusinessRules_2015.parquet",
        "2014": "BusinessRules_2014.parquet"
    },
    "Crosswalk2015": {
        "data": "Crosswalk2015_data.parquet"
    },
    "Crosswalk2016": {
        "data": "Crosswalk2016_data.parquet"
    },
    "Network": {
        # 2016 renamed DentalOnly => DentalOnlyPlan
        "2016": "Network_2016.parquet",
        "2015": "Network_2015.parquet",
        "2014": "Network_2014.parquet"
    },
    "PlanAttributes": {
        # This is complicated - lots of fields change b/t 2014/2015 & 2016
        "2016": "PlanAttributes_2016.parquet",
        "2015": "PlanAttributes_2015.parquet",
        "2014": "PlanAttributes_2014.parquet"
    },
    "Rate": {
        # 2016 same structure as 2015 and 2014
        "2016": "Rate_2016.parquet",
        "2015": "Rate_2015.parquet",
        "2014": "Rate_2014.parquet"
    },
    "ServiceArea": {
        # 2016 renamed DentalOnly => DentalOnlyPlan
        "2016": "ServiceArea_2016.parquet",
        "2015": "ServiceArea_2015.parquet",
        "2014": "ServiceArea_2014.parquet"
    }
}

# %%
pre_path = 'processed_data/data'

# %%
for table in tables:
    print(table)

    if table[:9] != "Crosswalk":
        d2016 = pd.read_csv(pre_path + tables[table]["2016"], encoding="latin1", low_memory=False)
        d2015 = pd.read_csv(pre_path + tables[table]["2015"], encoding="latin1", low_memory=False)
        d2014 = pd.read_csv(pre_path + tables[table]["2014"], encoding="latin1", low_memory=False)


        if table in ["ServiceArea", "BusinessRules", "Network"]:
            d2015 = d2015.rename(columns={"DentalOnly":"DentalOnlyPlan"})
            d2014 = d2014.rename(columns={"DentalOnly":"DentalOnlyPlan"})

        if table=="BenefitsCostSharing":
            d2015 = d2015.rename(columns={"EHBPercentPremiumS4":"EHBPercentTotalPremium"})
            d2014 = d2014.rename(columns={"EHBPercentPremiumS4":"EHBPercentTotalPremium"})

        if table != "Crosswalk":
            data = pd.concat([d2014, d2015, d2016])
        else:
            data = pd.concat([d2015, d2016])
    else:
        data = pd.read_csv(pre_path + tables[table]["data"], encoding="latin1", low_memory=False)

    print(data.shape)
# Out:
# BenefitsCostSharing
# (5048408, 32)
# BusinessRules
# (21085, 23)
# Crosswalk2015
# (132505, 21)
# Crosswalk2016
# (150005, 21)
# Network
# (3822, 14)
# PlanAttributes
# (77353, 176)
# Rate
# (12694445, 24)
# ServiceArea
# (42247, 18)
